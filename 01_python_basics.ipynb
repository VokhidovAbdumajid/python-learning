# %% [markdown]
# <a href="https://colab.research.google.com/github/VokhidovAbdumajid/python-learning/blob/main/01_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pulse = [120, 85, 200, 150, 95, 110, 80]

total = sum(pulse)
count = len(pulse)

average = total / count

print("Average pulse:", average)
# Out:
# Average pulse: 120.0

# %%
pulse = [120, 85, 200, 150, 95, 110, 80]

print("Maximum pulse:", max(pulse))
print("Minimum pulse:", min(pulse))
# Out:
# Maximum pulse: 200
# Minimum pulse: 80

# %%
pulse = [120, 85, 200, 150, 95, 110, 80]

print("Count:", len(pulse))
print("Maximum:", max(pulse))
print("Minimum:", min(pulse))
print("Average:", sum(pulse) / len(pulse))
# Out:
# Count: 7
# Maximum: 200
# Minimum: 80
# Average: 120.0

# %%
pulse = 85

if pulse > 100:
    print("High pulse")

# %%
pulse = 85

if pulse > 100:
    print("High pulse")
else:
    print("Normal pulse")
# Out:
# Normal pulse

# %%
pulse = 150

if pulse > 100:
    print("High pulse")

if pulse > 140:
    print("Very high pulse")
# Out:
# High pulse
# Very high pulse

# %%
oxygen = 88
pulse = 150

if oxygen < 90:
    print("Low oxygen")

if pulse > 140:
    print("Very high pulse")
# Out:
# Low oxygen
# Very high pulse

# %%
pulse = 120

if pulse > 140:
    print("Very high pulse")
elif pulse > 100:
    print("High pulse")
else:
    print("Normal pulse")
# Out:
# High pulse

# %%
pulse = [120, 85, 200]

for p in pulse:
    print(p)
# Out:
# 120
# 85
# 200

# %%
pulse = [120, 85, 200]

for p in pulse:
    print(p + 10)
# Out:
# 130
# 95
# 210

# %%
pulse = [120, 85, 200]

for p in pulse:
    if p > 100:
        print("High pulse")
    else:
        print("Normal pulse")
# Out:
# High pulse
# Normal pulse
# High pulse

# %%
pulse = [120 , 85, 200]

for p in pulse:
  if p > 100:
    print(p, "-> High pulse")
  else:
      print(p, "-> Normal pulse")
# Out:
# 120 -> High pulse
# 85 -> Normal pulse
# 200 -> High pulse

# %%
def check_pulse(pulse):
    if pulse > 100:
        print("High pulse")
    else:
        print("Normal pulse")

check_pulse(90)
check_pulse(150)
# Out:
# Normal pulse
# High pulse
